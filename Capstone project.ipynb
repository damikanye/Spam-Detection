# %%
import pandas as pd

# %%
dataset = pd.read_csv('downloads/suicide.csv')

# %%
serious = pd.read_csv('downloads/vital.csv')

# %%
dataset.head()
# Out:
#    Record Number  Year Age Group (in years)  Gender
# 0              1  2012                 ≤ 29  FEMALE
# 1              2  2012                 ≤ 29  FEMALE
# 2              3  2012                 ≤ 29    MALE
# 3              4  2012                 ≤ 29    MALE
# 4              5  2012                 ≤ 29    MALE

# %%
serious.head()
# Out:
#    Year Region   Race or Ethnicity Sex Age Group  Firearm Deaths  \
# 0  2016    ROS  White Non Hispanic   F     Total              40
# 1  2016    NYC  Other Non Hispanic   F     Total               0
# 2  2016    ROS  Other Non Hispanic   M     65-74               0
# 3  2016    NYC          Not Stated   M     35-44               1
# 4  2016    NYC  White Non Hispanic   M     55-64               4
#
#    Alcohol-Related Deaths  Suicide Deaths
# 0                     746             202
# 1                      27              30
# 2                       7               1
# 3                       2               3
# 4                     149              45

# %%
suicide = pd.read_csv('downloads/foreveralone.csv')

# %%
suicide.head()
# Out:
#                  time gender sexuallity  age              income  \
# 0  5/17/2016 20:04:18   Male   Straight   35  $30,000 to $39,999
# 1  5/17/2016 20:04:30   Male   Bisexual   21       $1 to $10,000
# 2  5/17/2016 20:04:58   Male   Straight   22                  $0
# 3  5/17/2016 20:08:01   Male   Straight   19       $1 to $10,000
# 4  5/17/2016 20:08:04   Male   Straight   23  $30,000 to $39,999
#
#                  race     bodyweight virgin prostitution_legal  \
# 0  White non-Hispanic  Normal weight    Yes                 No
# 1  White non-Hispanic    Underweight    Yes                 No
# 2  White non-Hispanic     Overweight    Yes                 No
# 3  White non-Hispanic     Overweight    Yes                Yes
# 4  White non-Hispanic     Overweight     No                 No
#
#       pay_for_sex  friends social_fear depressed  \
# 0              No      0.0         Yes       Yes
# 1              No      0.0         Yes       Yes
# ...
